# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\santh\OneDrive\Desktop\Sooraj S Internship doc\sales_data_sample.csv",encoding='latin1')

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df['ORDERDATE']=pd.to_datetime(df['ORDERDATE'],errors='coerce')

# %%
sns.set(style="whitegrid")

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=df.sort_values('ORDERDATE'), x='ORDERDATE', y='SALES')
plt.title("Sales Over Time")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df,x='DEALSIZE',y='SALES',estimator='mean',ci=None)
plt.title("Average Sales by Deal Size")
plt.show()
# Out:
# C:\Users\santh\AppData\Local\Temp\ipykernel_15112\2893882562.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df,x='DEALSIZE',y='SALES',estimator='mean',ci=None)

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df,x='PRICEEACH',y='STATUS')
plt.title("Price Distribution by Order Status")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df,x='QUANTITYORDERED',y='SALES',hue='DEALSIZE')
plt.title("Quantity vs Sales by Deal Size")
plt.show()
plt.xlabel("Quantity Ordered")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()
