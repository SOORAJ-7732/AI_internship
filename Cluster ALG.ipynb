# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\santh\OneDrive\Desktop\Sooraj S Internship doc\sales_data_sample.csv",encoding='latin1')

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
sns.pairplot(df)
plt.show()

# %%
import sklearn.cluster as cluster

# %%
kmeans = cluster.KMeans(n_clusters = 6)

# %%
kmeans=kmeans.fit(df[['ORDERNUMBER','SALES']])

# %%
kmeans.cluster_centers_
# Out:
# array([[10265.36320755,  6838.74339623],
#        [10257.22496372,  1615.30152395],
#        [10258.00309119,  3869.95848532],
#        [10283.89333333,  9265.8932    ],
#        [10256.43905473,  2730.78502488],
#        [10258.83585859,  5241.20255051]])

# %%
df['clusters']=kmeans.labels_

# %%
df['clusters']
# Out:
# 0       4
# 1       4
# 2       2
# 3       2
# 4       5
#        ..
# 2818    4
# 2819    2
# 2820    5
# 2821    1
# 2822    4
# Name: clusters, Length: 2823, dtype: int32

# %%
df.head(15)
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0         10107               30      95.70                2  2871.00
# 1         10121               34      81.35                5  2765.90
# 2         10134               41      94.74                2  3884.34
# 3         10145               45      83.26                6  3746.70
# 4         10159               49     100.00               14  5205.27
# 5         10168               36      96.66                1  3479.76
# 6         10180               29      86.13                9  2497.77
# 7         10188               48     100.00                1  5512.32
# 8         10201               22      98.57                2  2168.54
# 9         10211               41     100.00               14  4708.44
# 10        10223               37     100.00                1  3965.66
# 11        10237               23     100.00                7  2333.12
# ...

# %%
df['clusters'].value_counts()
# Out:
# clusters
# 4    805
# 1    684
# 2    648
# 5    399
# 0    212
# 3     75
# Name: count, dtype: int64

# %%
sns.scatterplot(x ='ORDERLINENUMBER', y='MONTH_ID', hue='clusters', data=df)
# Out:
# <Axes: xlabel='ORDERLINENUMBER', ylabel='MONTH_ID'>

# %%
from sklearn.cluster import KMeans

# %%
K_range=range(1,15)
AK=[]

# %%
for k in K_range:
    km = KMeans(n_clusters=k)
    km.fit(df[['QUANTITYORDERED','SALES']])
    AK.append(km.inertia_)  #Inertia_ is the sum of squared error for each cluster.

# %%
AK
# Out:
# [9573809860.855595,
#  3321660281.248888,
#  1731090570.8740008,
#  1040857403.6182103,
#  712700548.790496,
#  525871646.8805789,
#  383902723.26902294,
#  295224703.5560059,
#  239914337.1359407,
#  188061842.8210889,
#  155543612.06594145,
#  137912659.4951458,
#  111319734.14101768,
#  103853953.52434011]

# %%
plt.xlabel('Number of clusters (K)') 
plt.ylabel('Sum of squared error') 
plt.plot(K_range,AK) 
plt.title('My Shop')
# Out:
# Text(0.5, 1.0, 'My Shop')

# %%
kmeans2 = cluster.KMeans(n_clusters = 4)

# %%
kmeans2 = kmeans2.fit(df[['ORDERNUMBER']])

# %%
Kmeans2.cluster_centers_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 Kmeans2.cluster_centers_
#
# NameError: name 'Kmeans2' is not defined

# %%
df['age_clusters'] = kmeans2.labels_

# %%
df['age_clusters'].value_counts()
# Out:
# age_clusters
# 2    520
# 0    484
# 3    459
# 1    456
# 4    455
# 5    449
# Name: count, dtype: int64

# %%
sn.scatterplot(x='', y='Cost',hue='age_clusters',data=df)
